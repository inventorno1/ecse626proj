# %%
import numpy as np
from common.utils import plot_brain_3_views
import torch
import matplotlib.pyplot as plt
import os

# %%
brain_data_list = []

# %%
for b in range(8):
    brain_data = np.load(f'/cim/ehoney/ecse626proj/experiments/experiment14/generated_data/{{GPU=5}}_{{iteration=0}}_{{batch={b}}}.npy')
    plot_brain_3_views(brain_data)
    brain_data_list.append(brain_data)

# %%
data_dir = '/cim/ehoney/ecse626proj/experiments/experiment14/1500epochs/generated_data'

# %%
data_list = os.listdir(data_dir)

# %%
import random

# %%
random_files = random.sample(data_list, 5)

# %%
random_files
# Out:
# ['{GPU=6}_{iteration=12}_{batch=2}.npy',
#  '{GPU=6}_{iteration=6}_{batch=10}.npy',
#  '{GPU=6}_{iteration=13}_{batch=11}.npy',
#  '{GPU=5}_{iteration=15}_{batch=3}.npy',
#  '{GPU=0}_{iteration=2}_{batch=0}.npy']

# %%
# counter = 0
# for item in os.listdir(data_dir):
#     if not item.endswith('.npy'):
#         continue
#     counter += 1
#     path = os.path.join(data_dir, item)
#     brain_data = np.load(path)
#     # plot_brain_3_views(brain_data)
# print(f'Total data = {counter}')

# %%
for item in random_files:
    path = os.path.join(data_dir, item)
    brain_data = np.load(path)
    plot_brain_3_views(brain_data)
